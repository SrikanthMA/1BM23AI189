# %% [markdown]
# <a href="https://colab.research.google.com/github/SrikanthMA/1BM23AI189/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


def cost_function(x):
    a = 20
    b = 0.2
    c = 2 * math.pi
    d = len(x)

    term1 = -a * np.exp(-b * np.sqrt(np.sum(x**2) / d))
    term2 = -np.exp(np.sum(np.cos(c * x)) / d)

    return term1 + term2 + a + math.e


DIMENSIONS = 2
POPULATION = 30
MAX_ITER = 100

MIN_BOUND = -5
MAX_BOUND = 5

w = 0.7
c1 = 1.5
c2 = 1.5
V_MAX = 0.5


class Particle:
    def __init__(self):
        self.position = np.random.uniform(MIN_BOUND, MAX_BOUND, DIMENSIONS)
        self.velocity = np.random.uniform(-V_MAX, V_MAX, DIMENSIONS)
        self.best_position = self.position.copy()
        self.best_fitness = cost_function(self.position)
        self.fitness = self.best_fitness


def particle_swarm_optimization():
    swarm = [Particle() for _ in range(POPULATION)]


    gbest_position = swarm[0].best_position.copy()
    gbest_fitness = swarm[0].best_fitness

    for particle in swarm:
        if particle.best_fitness < gbest_fitness:
            gbest_fitness = particle.best_fitness
            gbest_position = particle.best_position.copy()


    for iteration in range(MAX_ITER):
        for particle in swarm:
            r1 = np.random.rand(DIMENSIONS)
            r2 = np.random.rand(DIMENSIONS)

            particle.velocity = (
                w * particle.velocity
                + c1 * r1 * (particle.best_position - particle.position)
                + c2 * r2 * (gbest_position - particle.position)
            )

            particle.velocity = np.clip(particle.velocity, -V_MAX, V_MAX)


            particle.position = particle.position + particle.velocity
            particle.position = np.clip(particle.position, MIN_BOUND, MAX_BOUND)


            particle.fitness = cost_function(particle.position)


            if particle.fitness < particle.best_fitness:
                particle.best_fitness = particle.fitness
                particle.best_position = particle.position.copy()


            if particle.fitness < gbest_fitness:
                gbest_fitness = particle.fitness
                gbest_position = particle.position.copy()

        print(f"Iteration {iteration+1}/{MAX_ITER}, Best Fitness = {gbest_fitness:.6f}")

    return gbest_position, gbest_fitness


if __name__ == "__main__":
    best_position, best_fitness = particle_swarm_optimization()

    print("\nOptimal Solution Found:")
    print("Best Position:", best_position)
    print("Best Fitness:", best_fitness)
# Out:
# Iteration 1/100, Best Fitness = 3.837247
# Iteration 2/100, Best Fitness = 3.090820
# Iteration 3/100, Best Fitness = 2.505761
# Iteration 4/100, Best Fitness = 1.832277
# Iteration 5/100, Best Fitness = 1.391202
# Iteration 6/100, Best Fitness = 0.207769
# Iteration 7/100, Best Fitness = 0.207769
# Iteration 8/100, Best Fitness = 0.207769
# Iteration 9/100, Best Fitness = 0.106400
# Iteration 10/100, Best Fitness = 0.053129
# Iteration 11/100, Best Fitness = 0.053129
# Iteration 12/100, Best Fitness = 0.053129
# Iteration 13/100, Best Fitness = 0.023524
# Iteration 14/100, Best Fitness = 0.023524
# Iteration 15/100, Best Fitness = 0.023524
# Iteration 16/100, Best Fitness = 0.019569
# Iteration 17/100, Best Fitness = 0.010889
# Iteration 18/100, Best Fitness = 0.010889
# Iteration 19/100, Best Fitness = 0.010889
# Iteration 20/100, Best Fitness = 0.007033
# Iteration 21/100, Best Fitness = 0.007033
# Iteration 22/100, Best Fitness = 0.007033
# Iteration 23/100, Best Fitness = 0.007033
# Iteration 24/100, Best Fitness = 0.007033
# Iteration 25/100, Best Fitness = 0.007033
# Iteration 26/100, Best Fitness = 0.007033
# Iteration 27/100, Best Fitness = 0.004517
# Iteration 28/100, Best Fitness = 0.004517
# Iteration 29/100, Best Fitness = 0.004156
# Iteration 30/100, Best Fitness = 0.003951
# Iteration 31/100, Best Fitness = 0.001962
# Iteration 32/100, Best Fitness = 0.001954
# Iteration 33/100, Best Fitness = 0.001954
# Iteration 34/100, Best Fitness = 0.001830
# Iteration 35/100, Best Fitness = 0.000798
# Iteration 36/100, Best Fitness = 0.000798
# Iteration 37/100, Best Fitness = 0.000798
# Iteration 38/100, Best Fitness = 0.000798
# Iteration 39/100, Best Fitness = 0.000563
# Iteration 40/100, Best Fitness = 0.000563
# Iteration 41/100, Best Fitness = 0.000563
# Iteration 42/100, Best Fitness = 0.000348
# Iteration 43/100, Best Fitness = 0.000076
# Iteration 44/100, Best Fitness = 0.000076
# Iteration 45/100, Best Fitness = 0.000076
# Iteration 46/100, Best Fitness = 0.000076
# Iteration 47/100, Best Fitness = 0.000076
# Iteration 48/100, Best Fitness = 0.000076
# Iteration 49/100, Best Fitness = 0.000076
# Iteration 50/100, Best Fitness = 0.000076
# Iteration 51/100, Best Fitness = 0.000076
# Iteration 52/100, Best Fitness = 0.000076
# Iteration 53/100, Best Fitness = 0.000076
# Iteration 54/100, Best Fitness = 0.000075
# Iteration 55/100, Best Fitness = 0.000075
# Iteration 56/100, Best Fitness = 0.000075
# Iteration 57/100, Best Fitness = 0.000075
# Iteration 58/100, Best Fitness = 0.000075
# Iteration 59/100, Best Fitness = 0.000064
# Iteration 60/100, Best Fitness = 0.000064
# Iteration 61/100, Best Fitness = 0.000046
# Iteration 62/100, Best Fitness = 0.000046
# Iteration 63/100, Best Fitness = 0.000046
# Iteration 64/100, Best Fitness = 0.000046
# Iteration 65/100, Best Fitness = 0.000046
# Iteration 66/100, Best Fitness = 0.000046
# Iteration 67/100, Best Fitness = 0.000046
# Iteration 68/100, Best Fitness = 0.000025
# Iteration 69/100, Best Fitness = 0.000025
# Iteration 70/100, Best Fitness = 0.000023
# Iteration 71/100, Best Fitness = 0.000023
# Iteration 72/100, Best Fitness = 0.000010
# Iteration 73/100, Best Fitness = 0.000010
# Iteration 74/100, Best Fitness = 0.000010
# Iteration 75/100, Best Fitness = 0.000010
# Iteration 76/100, Best Fitness = 0.000010
# Iteration 77/100, Best Fitness = 0.000010
# Iteration 78/100, Best Fitness = 0.000009
# Iteration 79/100, Best Fitness = 0.000009
# Iteration 80/100, Best Fitness = 0.000002
# Iteration 81/100, Best Fitness = 0.000002
# Iteration 82/100, Best Fitness = 0.000002
# Iteration 83/100, Best Fitness = 0.000002
# Iteration 84/100, Best Fitness = 0.000001
# Iteration 85/100, Best Fitness = 0.000001
# Iteration 86/100, Best Fitness = 0.000001
# Iteration 87/100, Best Fitness = 0.000001
# Iteration 88/100, Best Fitness = 0.000001
# Iteration 89/100, Best Fitness = 0.000001
# Iteration 90/100, Best Fitness = 0.000001
# Iteration 91/100, Best Fitness = 0.000001
# Iteration 92/100, Best Fitness = 0.000001
# Iteration 93/100, Best Fitness = 0.000001
# Iteration 94/100, Best Fitness = 0.000001
# Iteration 95/100, Best Fitness = 0.000001
# Iteration 96/100, Best Fitness = 0.000001
# Iteration 97/100, Best Fitness = 0.000001
# Iteration 98/100, Best Fitness = 0.000001
# Iteration 99/100, Best Fitness = 0.000001
# Iteration 100/100, Best Fitness = 0.000000
#
# Optimal Solution Found:
# Best Position: [1.56441425e-07 7.32835895e-08]
# Best Fitness: 4.886266542492024e-07

# %% [markdown]
# ![image.png](data:image/png;base64,...)
